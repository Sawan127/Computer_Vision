# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
# from skimage.io import imread,imshow

# %% [markdown]
# 1. Create image using opencv

# %%
# Use numpy to create an array of color
image_height = 300
image_width = 300
number_of_color_channels = 3
color = (0,0,255)
pixel_array = np.full((image_height,image_width,number_of_color_channels),color,dtype=np.uint8)
plt.title("images")
plt.imshow(pixel_array)
plt.show()

# %%
# conversion of image format from BGR TO RGB
img = cv2.cvtColor(pixel_array,cv2.COLOR_BGR2RGB)
plt.title("RGB IMAGE")
plt.imshow(img)
plt.show()

# %%
# Gray Scale image
img_gray=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
plt.title('Gray Scale')
plt.imshow(img_gray)
plt.show()

# %% [markdown]
# 2. Image properties include number of rows, columns, and channels; type of image data; number of pixels; etc.

# %% [markdown]
# Shape:
#
# The shape of an image is accessed by img.shape. It returns a tuple of the number of rows, columns, and channels (if the image is color)
#
# If an image is grayscale, the tuple returned contains only the number of rows and columns, so it is a good method to check whether the loaded image is grayscale or color.

# %%
# Color Image
print(img.shape)
# Out:
# (300, 300, 3)

# %%
# Gray Scale Image
print(img_gray.shape)
# Out:
# (300, 300)

# %% [markdown]
# Total number of pixels is accessed by img.size:

# %%
print(img.size)
# Out:
# 270000

# %% [markdown]
# Data Type
#
# Image datatype is obtained by `img.dtype`:
#
# img.dtype is very important while debugging because a large number of errors in OpenCV-Python code are caused by invalid datatype.

# %%
print(img.dtype)
# Out:
# uint8

# %% [markdown]
# 3. Accessing Pixel

# %%
px =img[100,100]
print(px)
# Out:
# [255   0   0]

# %%
blue = img[100,100,0] # blue pixel
print('Blue pixel: ',blue)
img[10,10,2] # red pixel
# Out:
# Blue pixel:  255
# 0
